# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("https://www.magicbricks.com/project-south-city-for-rent-in-kolkata-pppfr")
c = r.content

soup = BeautifulSoup(c,"html.parser")


all = soup.find_all("div",{"class":"m-srp-card SRCard"})

# %%
l = []
for item in all:
    d = {}
    d["Price"] = item.find("div",{"class":"m-srp-card__price"}).text.replace("\n","")
    d["BHK"] = item.find("span",{"class":"m-srp-card__title__bhk"}).text.replace("\n","")
    d["Furnishing"] = item.find_all("div",{"class":"m-srp-card__summary__info"})[1].text
    d["Available for"] = item.find_all("div",{"class":"m-srp-card__summary__info"})[2].text
    d["Bathrooms"] = item.find_all("div",{"class":"m-srp-card__summary__info"})[3].text
    l.append(d)
l
# Out:
# [{'Price': '₹52,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '3'},
#  {'Price': '₹40,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Semi-Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'},
#  {'Price': '₹55,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'},
#  {'Price': '₹60,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'},
#  {'Price': '₹50,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'},
#  {'Price': '₹41,000',
#   'BHK': '2 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors',
#   'Bathrooms': '2'},
#  {'Price': '₹40,000',
#   'BHK': '2 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'},
#  {'Price': '₹43,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Semi-Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'},
#  {'Price': '₹60,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Family',
#   'Bathrooms': '2'},
#  {'Price': '₹53,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '3'},
#  {'Price': '₹55,000',
#   'BHK': '3 BHK House',
#   'Furnishing': 'Semi-Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '3'},
#  {'Price': '₹50,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'},
#  {'Price': '₹45,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'},
#  {'Price': '₹45,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'},
#  {'Price': '₹48,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'},
#  {'Price': '₹70,000',
#   'BHK': '4 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors',
#   'Bathrooms': '4'},
#  {'Price': '₹43,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Unfurnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'},
#  {'Price': '₹45,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors',
#   'Bathrooms': '2'},
#  {'Price': '₹45,000',
#   'BHK': '2 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'},
#  {'Price': '₹70,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors',
#   'Bathrooms': '3'},
#  {'Price': '₹40,000',
#   'BHK': '2 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'},
#  {'Price': '₹48,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Semi-Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '3'},
#  {'Price': '₹50,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'},
#  {'Price': '₹44,000',
#   'BHK': '3 BHK Builder Floor',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'},
#  {'Price': '₹75,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'},
#  {'Price': '₹60,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'},
#  {'Price': '₹65,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Furnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '3'},
#  {'Price': '₹55,000',
#   'BHK': '3 BHK Apartment',
#   'Furnishing': 'Unfurnished',
#   'Available for': 'Bachelors/Family',
#   'Bathrooms': '2'}]

# %%
import pandas
df = pandas.DataFrame(l)

# %%
df
# Out:
#       Price                  BHK      Furnishing     Available for Bathrooms
# 0   ₹52,000      3 BHK Apartment       Furnished  Bachelors/Family         3
# 1   ₹40,000      3 BHK Apartment  Semi-Furnished  Bachelors/Family         2
# 2   ₹55,000      3 BHK Apartment       Furnished  Bachelors/Family         2
# 3   ₹60,000      3 BHK Apartment       Furnished  Bachelors/Family         2
# 4   ₹50,000      3 BHK Apartment       Furnished  Bachelors/Family         2
# 5   ₹41,000      2 BHK Apartment       Furnished         Bachelors         2
# 6   ₹40,000      2 BHK Apartment       Furnished  Bachelors/Family         2
# 7   ₹43,000      3 BHK Apartment  Semi-Furnished  Bachelors/Family         2
# 8   ₹60,000      3 BHK Apartment       Furnished            Family         2
# 9   ₹53,000      3 BHK Apartment       Furnished  Bachelors/Family         3
# 10  ₹55,000          3 BHK House  Semi-Furnished  Bachelors/Family         3
# 11  ₹50,000      3 BHK Apartment       Furnished  Bachelors/Family         2
# 12  ₹45,000      3 BHK Apartment       Furnished  Bachelors/Family         2
# 13  ₹45,000      3 BHK Apartment       Furnished  Bachelors/Family         2
# 14  ₹48,000      3 BHK Apartment       Furnished  Bachelors/Family         2
# 15  ₹70,000      4 BHK Apartment       Furnished         Bachelors         4
# 16  ₹43,000      3 BHK Apartment     Unfurnished  Bachelors/Family         2
# 17  ₹45,000      3 BHK Apartment       Furnished         Bachelors         2
# 18  ₹45,000      2 BHK Apartment       Furnished  Bachelors/Family         2
# 19  ₹70,000      3 BHK Apartment       Furnished         Bachelors         3
# 20  ₹40,000      2 BHK Apartment       Furnished  Bachelors/Family         2
# 21  ₹48,000      3 BHK Apartment  Semi-Furnished  Bachelors/Family         3
# 22  ₹50,000      3 BHK Apartment       Furnished  Bachelors/Family         2
# 23  ₹44,000  3 BHK Builder Floor       Furnished  Bachelors/Family         2
# 24  ₹75,000      3 BHK Apartment       Furnished  Bachelors/Family         2
# 25  ₹60,000      3 BHK Apartment       Furnished  Bachelors/Family         2
# 26  ₹65,000      3 BHK Apartment       Furnished  Bachelors/Family         3
# 27  ₹55,000      3 BHK Apartment     Unfurnished  Bachelors/Family         2

# %%
df.to_csv("Output.csv")
